# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
from  sklearn.model_selection import train_test_split

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is F29B-0A1E
#
#  Directory of C:\Users\sylve\OneDrive\Documents\ExcelR\My project
#
# 05/24/2022  02:07 PM    <DIR>          .
# 05/20/2022  09:12 AM    <DIR>          ..
# 05/20/2022  09:05 PM    <DIR>          .ipynb_checkpoints
# 05/23/2022  06:13 PM           423,059 final.ipynb
# 05/23/2022  04:39 PM            15,665 Log_ROC.png
# 05/20/2022  09:50 PM         1,083,973 Telecom.ipynb
# 05/19/2022  03:00 PM         5,940,089 Telecommunication churn Project.ipynb
# 04/29/2022  11:33 PM           255,610 telecommunications_churn.csv
# 05/19/2022  12:41 PM        19,073,415 Untitled.ipynb
# 05/24/2022  02:07 PM                 0 untitled.txt
# 05/19/2022  04:58 PM        14,066,566 Untitled1.ipynb
#                8 File(s)     40,858,377 bytes
#                3 Dir(s)  122,491,252,736 bytes free

# %%
df=pd.read_csv('telecommunications_churn.csv')

# %%
df
# Out:
#      account_length;voice_mail_plan;voice_mail_messages;day_mins;evening_mins;night_mins;international_mins;customer_service_calls;international_plan;day_calls;day_charge;evening_calls;evening_charge;night_calls;night_charge;international_calls;international_charge;total_charge;churn
# 0     128;1;25;265.1;197.4;244.7;10;1;0;110;45.07;99...
# 1     107;1;26;161.6;195.5;254.4;13.7;1;0;123;27.47;...
# 2     137;0;0;243.4;121.2;162.6;12.2;0;0;114;41.38;1...
# 3     84;0;0;299.4;61.9;196.9;6.6;2;1;71;50.9;88;5.2...
# 4     75;0;0;166.7;148.3;186.9;10.1;3;1;113;28.34;12...
# ...                                                 ...
# 3328  192;1;36;156.2;215.5;279.1;9.9;2;0;77;26.55;12...
# 3329  68;0;0;231.1;153.4;191.3;9.6;3;0;57;39.29;55;1...
# 3330  28;0;0;180.8;288.8;191.9;14.1;2;0;109;30.74;58...
# 3331  184;0;0;213.8;159.6;139.2;5;2;1;105;36.35;84;1...
# 3332  74;1;25;234.4;265.9;241.4;13.7;0;0;113;39.85;8...
#
# [3333 rows x 1 columns]

# %%
df[['account_length', 'voice_mail_plan', 'voice_mail_messages', 'day_mins', 'evening_mins', 'night_mins', 'international_mins', 'customer_service_calls', 'international_plan', 'day_calls', 'day_charge', 'evening_calls', 'evening_charge', 'night_calls', 'night_charge', 'international_calls', 'international_charge', 'total_charge', 'churn']] = df['account_length;voice_mail_plan;voice_mail_messages;day_mins;evening_mins;night_mins;international_mins;customer_service_calls;international_plan;day_calls;day_charge;evening_calls;evening_charge;night_calls;night_charge;international_calls;international_charge;total_charge;churn'].str.split(';', expand=True)

# %%
Tele=df.copy()

# %%
new=Tele.drop('account_length;voice_mail_plan;voice_mail_messages;day_mins;evening_mins;night_mins;international_mins;customer_service_calls;international_plan;day_calls;day_charge;evening_calls;evening_charge;night_calls;night_charge;international_calls;international_charge;total_charge;churn', axis=1)

# %%
new.head()
# Out:
#   account_length voice_mail_plan voice_mail_messages day_mins evening_mins  \
# 0            128               1                  25    265.1        197.4
# 1            107               1                  26    161.6        195.5
# 2            137               0                   0    243.4        121.2
# 3             84               0                   0    299.4         61.9
# 4             75               0                   0    166.7        148.3
#
#   night_mins international_mins customer_service_calls international_plan  \
# 0      244.7                 10                      1                  0
# 1      254.4               13.7                      1                  0
# 2      162.6               12.2                      0                  0
# 3      196.9                6.6                      2                  1
# 4      186.9               10.1                      3                  1
#
# ...

# %%
Telecommunication=new.copy()

# %%
Telecommunication.head()
# Out:
#   account_length voice_mail_plan voice_mail_messages day_mins evening_mins  \
# 0            128               1                  25    265.1        197.4
# 1            107               1                  26    161.6        195.5
# 2            137               0                   0    243.4        121.2
# 3             84               0                   0    299.4         61.9
# 4             75               0                   0    166.7        148.3
#
#   night_mins international_mins customer_service_calls international_plan  \
# 0      244.7                 10                      1                  0
# 1      254.4               13.7                      1                  0
# 2      162.6               12.2                      0                  0
# 3      196.9                6.6                      2                  1
# 4      186.9               10.1                      3                  1
#
# ...

# %%
Telecommunication.tail(45)
# Out:
#       account_length  voice_mail_plan  voice_mail_messages  day_mins  \
# 3288              78                0                    0     109.5
# 3289              39                0                    0     187.2
# 3290             127                0                    0     107.9
# 3291             119                1                   22     172.1
# 3292             114                0                    0     203.8
# 3293              95                0                    0     160.0
# 3294             116                0                    0      51.1
# 3295             110                0                    0     227.7
# 3296              74                0                    0     203.8
# 3297             148                1                   33     241.7
# 3298              83                0                    0      78.1
# 3299              73                0                    0     187.8
# 3300             111                1                   21     127.1
# ...

# %%
Telecommunication.size
# Out:
# 63327

# %%
Telecommunication.shape
# Out:
# (3333, 19)

# %% [markdown]
# # Check for missing values

# %%
Telecommunication.isnull().sum()
# Out:
# account_length            0
# voice_mail_plan           0
# voice_mail_messages       0
# day_mins                  0
# evening_mins              0
# night_mins                0
# international_mins        0
# customer_service_calls    0
# international_plan        0
# day_calls                 0
# day_charge                0
# evening_calls             0
# evening_charge            0
# night_calls               0
# night_charge              0
# international_calls       0
# international_charge      0
# total_charge              0
# churn                     0
# dtype: int64

# %% [markdown]
# # check the data types of each attribute.

# %%
Telecommunication.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   account_length          3333 non-null   object
#  1   voice_mail_plan         3333 non-null   object
#  2   voice_mail_messages     3333 non-null   object
#  3   day_mins                3333 non-null   object
#  4   evening_mins            3333 non-null   object
#  5   night_mins              3333 non-null   object
#  6   international_mins      3333 non-null   object
#  7   customer_service_calls  3333 non-null   object
#  8   international_plan      3333 non-null   object
#  9   day_calls               3333 non-null   object
#  10  day_charge              3333 non-null   object
#  11  evening_calls           3333 non-null   object
#  12  evening_charge          3333 non-null   object
#  13  night_calls             3333 non-null   object
# ...

# %%
Telecommunication=Telecommunication.apply(pd.to_numeric,errors='coerce').fillna(0)

# %%
Telecommunication.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   account_length          3333 non-null   int64
#  1   voice_mail_plan         3333 non-null   int64
#  2   voice_mail_messages     3333 non-null   int64
#  3   day_mins                3333 non-null   float64
#  4   evening_mins            3333 non-null   float64
#  5   night_mins              3333 non-null   float64
#  6   international_mins      3333 non-null   float64
#  7   customer_service_calls  3333 non-null   int64
#  8   international_plan      3333 non-null   int64
#  9   day_calls               3333 non-null   int64
#  10  day_charge              3333 non-null   float64
#  11  evening_calls           3333 non-null   int64
#  12  evening_charge          3333 non-null   float64
#  13  night_calls             3333 non-null   int64
# ...

# %%
missing = pd.DataFrame((Telecommunication.isnull().sum())*100/Telecommunication.shape[0]).reset_index()
plt.figure(figsize=(16,5))
ax = sns.pointplot('index',0,data=missing)
plt.xticks(rotation =90,fontsize =7)
plt.title("Percentage of Missing values")
plt.ylabel("PERCENTAGE")
plt.show()

# %%
#Checking for wrong entries like symbols -,?,#,*,etc.
for col in Telecommunication.columns:
    print('{} : {}'.format(col,Telecommunication[col].unique()))
# Out:
# account_length : [128 107 137  84  75 118 121 147 117 141  65  74 168  95  62 161  85  93
#   76  73  77 130 111 132 174  57  54  20  49 142 172  12  72  36  78 136
#  149  98 135  34 160  64  59 119  97  52  60  10  96  87  81  68 125 116
#   38  40  43 113 126 150 138 162  90  50  82 144  46  70  55 106  94 155
#   80 104  99 120 108 122 157 103  63 112  41 193  61  92 131 163  91 127
#  110 140  83 145  56 151 139   6 115 146 185 148  32  25 179  67  19 170
#  164  51 208  53 105  66  86  35  88 123  45 100 215  22  33 114  24 101
#  143  48  71 167  89 199 166 158 196 209  16  39 173 129  44  79  31 124
#   37 159 194 154  21 133 224  58  11 109 102 165  18  30 176  47 190 152
#   26  69 186 171  28 153 169  13  27   3  42 189 156 134 243  23   1 205
#  200   5   9 178 181 182 217 177 210  29 180   2  17   7 212 232 192 195
#  197 225 184 191 201  15 183 202   8 175   4 188 204 221]
# voice_mail_plan : [1 0]
# ...

# %%
#Describe the data
Telecommunication.describe()
# Out:
#        account_length  voice_mail_plan  voice_mail_messages     day_mins  \
# count     3333.000000      3333.000000          3333.000000  3333.000000
# mean       101.064806         0.276628             8.099010   179.775098
# std         39.822106         0.447398            13.688365    54.467389
# min          1.000000         0.000000             0.000000     0.000000
# 25%         74.000000         0.000000             0.000000   143.700000
# 50%        101.000000         0.000000             0.000000   179.400000
# 75%        127.000000         1.000000            20.000000   216.400000
# max        243.000000         1.000000            51.000000   350.800000
#
#        evening_mins   night_mins  international_mins  customer_service_calls  \
# count   3333.000000  3333.000000         3333.000000             3333.000000
# mean     200.980348   200.872037           10.237294                1.562856
# std       50.713844    50.573847            2.791840                1.315491
# ...

# %% [markdown]
# The described method will help to see how data has been spread for numerical values. We can clearly see the minimum value, mean values, different percentile values, and maximum values.

# %%
plt.figure(figsize=(10,4))
Telecommunication["churn"].value_counts().plot(kind="pie",autopct="%1.1f%%",colormap='summer')
# Out:
# <AxesSubplot:ylabel='churn'>

# %%
Telecommunication['churn'].value_counts().plot(kind='barh', figsize=(8, 6))
plt.xlabel("Count", labelpad=14)
plt.ylabel("Target Variable", labelpad=14)
plt.title("Count of TARGET Variable per category", y=1.02)
# Out:
# Text(0.5, 1.02, 'Count of TARGET Variable per category')

# %%
#100*Telecommunication['churn'].value_counts()/len(Telecommunication['churn'])

# %%
#Let’s see the value count of our target variable

# %%
Telecommunication['churn'].value_counts()
# Out:
# 0    2850
# 1     483
# Name: churn, dtype: int64

# %% [markdown]
# # Handling Duplicate records

# %%
duplicate=Telecommunication.duplicated()
print(duplicate.sum())
Telecommunication[duplicate]
# Out:
# 0
# Empty DataFrame
# Columns: [account_length, voice_mail_plan, voice_mail_messages, day_mins, evening_mins, night_mins, international_mins, customer_service_calls, international_plan, day_calls, day_charge, evening_calls, evening_charge, night_calls, night_charge, international_calls, international_charge, total_charge, churn]
# Index: []

# %%
for i in Telecommunication.columns:
    print(i)
    print(Telecommunication[i].value_counts())
    print()
# Out:
# account_length
# 105    43
# 87     42
# 101    40
# 93     40
# 90     39
#        ..
# 243     1
# 200     1
# 232     1
# 5       1
# 221     1
# Name: account_length, Length: 212, dtype: int64
#
# voice_mail_plan
# 0    2411
# 1     922
# Name: voice_mail_plan, dtype: int64
#
# voice_mail_messages
# 0     2411
# 31      60
# 29      53
# 28      51
# 33      46
# 27      44
# 30      44
# 24      42
# 26      41
# 32      41
# 25      37
# 23      36
# 36      34
# 22      32
# 35      32
# 39      30
# 34      29
# 37      29
# 21      28
# 38      25
# 20      22
# 19      19
# 40      16
# 42      15
# 17      14
# 16      13
# 41      13
# 43       9
# 15       9
# 18       7
# 44       7
# 14       7
# 45       6
# 12       6
# 46       4
# 13       4
# 47       3
# 50       2
# 9        2
# 8        2
# 11       2
# 48       2
# 49       1
# 4        1
# 10       1
# 51       1
# Name: voice_mail_messages, dtype: int64
#
# day_mins
# 154.0    8
# 159.5    8
# 174.5    8
# ...

# %%
Telecommunication.corr()
# Out:
#                         account_length  voice_mail_plan  voice_mail_messages  \
# account_length                1.000000         0.002918            -0.004628
# voice_mail_plan               0.002918         1.000000             0.956927
# voice_mail_messages          -0.004628         0.956927             1.000000
# day_mins                      0.006216        -0.001684             0.000778
# evening_mins                 -0.006757         0.021545             0.017562
# night_mins                   -0.008955         0.006079             0.007681
# international_mins            0.009514        -0.001318             0.002856
# customer_service_calls       -0.003796        -0.017824            -0.013263
# international_plan            0.024735         0.006006             0.008745
# day_calls                     0.038470        -0.011086            -0.009548
# day_charge                    0.006214        -0.001686             0.000776
# ...

# %%
plt.figure(figsize=(14,10))
sns.heatmap(Telecommunication.corr(),cbar=True,annot=True,cmap='Blues')
# Out:
# <AxesSubplot:>

# %%
Telecommunication.head()
# Out:
#    account_length  voice_mail_plan  voice_mail_messages  day_mins  \
# 0             128                1                   25     265.1
# 1             107                1                   26     161.6
# 2             137                0                    0     243.4
# 3              84                0                    0     299.4
# 4              75                0                    0     166.7
#
#    evening_mins  night_mins  international_mins  customer_service_calls  \
# 0         197.4       244.7                10.0                       1
# 1         195.5       254.4                13.7                       1
# 2         121.2       162.6                12.2                       0
# 3          61.9       196.9                 6.6                       2
# 4         148.3       186.9                10.1                       3
#
#    international_plan  day_calls  day_charge  evening_calls  evening_charge  \
# ...

# %%
#Measure the churn by charges
Mth = sns.kdeplot(Telecommunication.total_charge[(Telecommunication["churn"] == 0) ],
                color="Red", shade = True)
Mth = sns.kdeplot(Telecommunication.total_charge[(Telecommunication["churn"] == 1) ],
                ax =Mth, color="Blue", shade= True)
Mth.legend(["No Churn","Churn"],loc='upper right')
Mth.set_ylabel('Density')
Mth.set_xlabel('total_charges')
Mth.set_title('total_charge by churn')
# Out:
# Text(0.5, 1.0, 'total_charge by churn')

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
pd.crosstab(index = Telecommunication['voice_mail_plan'], columns = 'count', dropna = True)
# Out:
# col_0            count
# voice_mail_plan
# 0                 2411
# 1                  922

# %%
sns.countplot(Telecommunication['voice_mail_plan'])
# Out:
# <AxesSubplot:xlabel='voice_mail_plan', ylabel='count'>

# %%
pd.crosstab(index = Telecommunication['international_plan'], columns = 'count', dropna = True)
# Out:
# col_0               count
# international_plan
# 0                    3010
# 1                     323

# %%
sns.countplot(Telecommunication['international_plan'])
# Out:
# <AxesSubplot:xlabel='international_plan', ylabel='count'>

# %%
pd.crosstab(index = Telecommunication['customer_service_calls'], columns = 'count', dropna = True)
# Out:
# col_0                   count
# customer_service_calls
# 0                         697
# 1                        1181
# 2                         759
# 3                         429
# 4                         166
# 5                          66
# 6                          22
# 7                           9
# 8                           2
# 9                           2

# %%
sns.countplot(x="customer_service_calls", data=Telecommunication,hue="customer_service_calls")
# Out:
# <AxesSubplot:xlabel='customer_service_calls', ylabel='count'>

# %%
# table 
pd.crosstab(Telecommunication.customer_service_calls,Telecommunication.voice_mail_plan)
# Out:
# voice_mail_plan           0    1
# customer_service_calls
# 0                       504  193
# 1                       837  344
# 2                       544  215
# 3                       331   98
# 4                       124   42
# 5                        49   17
# 6                        13    9
# 7                         7    2
# 8                         1    1
# 9                         1    1

# %%
plt.figure(figsize=(10,6))
Telecommunication["customer_service_calls"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

for i in Telecommunication.columns:
    print(i)
    sns.boxplot(Telecommunication[i],color = 'blue')
    plt.show()
# Out:
# account_length
# voice_mail_plan
# voice_mail_messages
# day_mins
# evening_mins
# night_mins
# international_mins
# customer_service_calls
# international_plan
# day_calls
# day_charge
# evening_calls
# evening_charge
# night_calls
# night_charge
# international_calls
# international_charge
# total_charge
# churn

# %%
#we see count of outliers by using z score
from scipy.stats import zscore
boxes = ['voice_mail_messages', 'day_mins', 'evening_mins', 'night_mins', 'international_mins', 'day_calls','day_charge','evening_calls','evening_charge','night_calls','night_charge','international_calls','international_charge','total_charge']
for i in boxes:
    print(i)
    z_scores = zscore(Telecommunication[i])
    print("*"*50)
    threshold = 3
    #for threshold in np.arange(1.5,5,0.5):
    print("Treshold: {}".format(threshold))
    print("Amount of Outliers: {}".format(len((np.where(z_scores > threshold)[0]))))
    print('------')
# Out:
# voice_mail_messages
# **************************************************
# Treshold: 3
# Amount of Outliers: 3
# ------
# day_mins
# **************************************************
# Treshold: 3
# Amount of Outliers: 3
# ------
# evening_mins
# **************************************************
# Treshold: 3
# Amount of Outliers: 3
# ------
# night_mins
# **************************************************
# Treshold: 3
# Amount of Outliers: 7
# ------
# international_mins
# **************************************************
# Treshold: 3
# Amount of Outliers: 2
# ------
# day_calls
# **************************************************
# Treshold: 3
# Amount of Outliers: 2
# ------
# day_charge
# **************************************************
# Treshold: 3
# Amount of Outliers: 3
# ------
# evening_calls
# **************************************************
# Treshold: 3
# Amount of Outliers: 3
# ------
# evening_charge
# **************************************************
# ...

# %%
Telecommunication.head(1)
# Out:
#    account_length  voice_mail_plan  voice_mail_messages  day_mins  \
# 0             128                1                   25     265.1
#
#    evening_mins  night_mins  international_mins  customer_service_calls  \
# 0         197.4       244.7                10.0                       1
#
#    international_plan  day_calls  day_charge  evening_calls  evening_charge  \
# 0                   0        110       45.07             99           16.78
#
#    night_calls  night_charge  international_calls  international_charge  \
# 0           91         11.01                    3                   2.7
#
#    total_charge  churn
# 0         75.56      0

# %%
fig, ax = plt.subplots(figsize=(10,6))
ax.scatter(Telecommunication['day_mins'], Telecommunication['total_charge'])
ax.set_xlabel('day_mins')
ax.set_ylabel('total_charge')
plt.show()

# %%
sns.histplot(Telecommunication.day_mins,bins=10)
# Out:
# <AxesSubplot:xlabel='day_mins', ylabel='Count'>

# %%
fig, ax = plt.subplots(figsize=(10,6))
ax.scatter(Telecommunication['evening_mins'], Telecommunication['total_charge'])
ax.set_xlabel('evening_mins')
ax.set_ylabel('total_charge')
plt.show()

# %%
sns.histplot(Telecommunication.evening_mins,bins=10)
# Out:
# <AxesSubplot:xlabel='evening_mins', ylabel='Count'>

# %%
fig, ax = plt.subplots(figsize=(10,6))
ax.scatter(Telecommunication['night_mins'], Telecommunication['total_charge'])
ax.set_xlabel('night_mins')
ax.set_ylabel('total_charge')
plt.show()

# %%
sns.histplot(Telecommunication.night_mins,bins=10)
# Out:
# <AxesSubplot:xlabel='night_mins', ylabel='Count'>

# %%
fig, ax = plt.subplots(figsize=(10,6))
ax.scatter(Telecommunication['day_charge'], Telecommunication['total_charge'])
ax.set_xlabel('day_charge')
ax.set_ylabel('total_charge')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,6))
ax.scatter(Telecommunication['evening_charge'], Telecommunication['total_charge'])
ax.set_xlabel('evening_charge')
ax.set_ylabel('total_charge')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,6))
ax.scatter(Telecommunication['night_charge'], Telecommunication['total_charge'])
ax.set_xlabel('night_charge')
ax.set_ylabel('total_charge')
plt.show()

# %%
#categorical variable analysis
def categorical_vis(variable):
    
    var = Telecommunication[variable].value_counts()
    
    x = var.index
    y = var
    if variable == "churn":
        plt.bar(x,y,edgecolor="#1F1F1F",color='#17869E')
        plt.title(variable,fontsize=12,fontweight="bold",color='#1F1F1F')
        plt.ylabel("Frequency")
        plt.xticks([0,1])
        plt.show()
        print("{}: \n {}".format(variable,var))
    else:
        plt.bar(x,y,edgecolor="#1F1F1F",color='#17869E')
        plt.title(variable,fontsize=12,fontweight="bold",color='#1F1F1F')
        plt.ylabel("Frequency")
        plt.show()
        print("{}: \n {}".format(variable,var))

# %%
categorical = ["voice_mail_plan","customer_service_calls","international_plan","international_calls","churn"]
for cat in categorical:
    categorical_vis(cat)
# Out:
# voice_mail_plan:
#  0    2411
# 1     922
# Name: voice_mail_plan, dtype: int64
# customer_service_calls:
#  1    1181
# 2     759
# 0     697
# 3     429
# 4     166
# 5      66
# 6      22
# 7       9
# 9       2
# 8       2
# Name: customer_service_calls, dtype: int64
# international_plan:
#  0    3010
# 1     323
# Name: international_plan, dtype: int64
# international_calls:
#  3     668
# 4     619
# 2     489
# 5     472
# 6     336
# 7     218
# 1     160
# 8     116
# 9     109
# 10     50
# 11     28
# 0      18
# 12     15
# 13     14
# 15      7
# 14      6
# 18      3
# 16      2
# 19      1
# 20      1
# 17      1
# Name: international_calls, dtype: int64
# churn:
#  0    2850
# 1     483
# Name: churn, dtype: int64

# %%
sns.boxplot(x="churn",y="day_mins",data=Telecommunication) #Boxplot on a Normal Distribution
# Out:
# <AxesSubplot:xlabel='churn', ylabel='day_mins'>

# %%
sns.boxplot(x="churn",y="evening_mins",data=Telecommunication)
# Out:
# <AxesSubplot:xlabel='churn', ylabel='evening_mins'>

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(15, 10))
sns.distplot(Telecommunication.day_mins)
plt.show()

# %% [markdown]
# # Train Test

# %%
X = Telecommunication.drop('churn',axis='columns')
y = Telecommunication['churn']
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=5)

# %%
X_train.shape
# Out:
# (2666, 18)

# %%
X_test.shape
# Out:
# (667, 18)

# %%
y_train.shape
# Out:
# (2666,)

# %%
y_test.shape
# Out:
# (667,)

# %%
X_train
# Out:
#       account_length  voice_mail_plan  voice_mail_messages  day_mins  \
# 1286             107                1                   14     114.3
# 1765             111                0                    0     132.6
# 2961              98                1                   36     168.0
# 1271              81                1                   37     237.1
# 869              127                0                    0     180.9
# ...              ...              ...                  ...       ...
# 3190             103                0                    0     174.7
# 3046             110                0                    0      18.9
# 1725              99                0                    0     128.8
# 2254              97                1                   28     202.3
# 2915              58                0                    0     210.1
#
#       evening_mins  night_mins  international_mins  customer_service_calls  \
# ...

# %% [markdown]
# # ANN MODEL

# %%
import tensorflow as tf
from tensorflow import keras

model = keras.Sequential([
    keras.layers.Dense(15, input_shape=(18,), activation='relu'),
    keras.layers.Dense(10, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])

# opt = keras.optimizers.Adam(learning_rate=0.01)

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

model.fit(X_train, y_train, epochs=100)
# Out:
# Epoch 1/100
# 84/84 [==============================] - 1s 2ms/step - loss: 6.9119 - accuracy: 0.4374
# Epoch 2/100
# 84/84 [==============================] - 0s 2ms/step - loss: 0.6306 - accuracy: 0.7839
# Epoch 3/100
# 84/84 [==============================] - 0s 2ms/step - loss: 0.5427 - accuracy: 0.8053
# Epoch 4/100
# 84/84 [==============================] - 0s 2ms/step - loss: 0.4899 - accuracy: 0.8290
# Epoch 5/100
# 84/84 [==============================] - 0s 2ms/step - loss: 0.4688 - accuracy: 0.8308
# Epoch 6/100
# 84/84 [==============================] - 0s 2ms/step - loss: 0.4419 - accuracy: 0.8436
# Epoch 7/100
# 84/84 [==============================] - 0s 2ms/step - loss: 0.4280 - accuracy: 0.8477
# Epoch 8/100
# 84/84 [==============================] - 0s 2ms/step - loss: 0.4209 - accuracy: 0.8533
# Epoch 9/100
# 84/84 [==============================] - 0s 2ms/step - loss: 0.4084 - accuracy: 0.8522
# Epoch 10/100
# ...

# %%
model.evaluate(X_test, y_test)
# Out:
# 21/21 [==============================] - 0s 2ms/step - loss: 0.2975 - accuracy: 0.8696
# [0.29748284816741943, 0.8695651888847351]

# %%
yp = model.predict(X_test)
yp[:5]
# Out:
# array([[0.08854017],
#        [0.10399944],
#        [0.03996286],
#        [0.06432903],
#        [0.3951178 ]], dtype=float32)

# %%
from sklearn.metrics import confusion_matrix , classification_report
yp = model.predict(X_test)
y_pred = []
for element in yp:
    if element > 0.5:
        y_pred.append(1)
    else:
        y_pred.append(0)
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.95      0.93       575
#            1       0.54      0.36      0.43        92
#
#     accuracy                           0.87       667
#    macro avg       0.72      0.66      0.68       667
# weighted avg       0.85      0.87      0.86       667

# %%
from sklearn.linear_model import LogisticRegression
logreg= LogisticRegression()
logreg.fit(X_train,y_train)
y_pred_lr=logreg.predict(X_test)
print(classification_report(y_test,y_pred_lr))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.99      0.92       575
#            1       0.50      0.09      0.15        92
#
#     accuracy                           0.86       667
#    macro avg       0.69      0.54      0.54       667
# weighted avg       0.82      0.86      0.82       667

# %%
from xgboost import XGBClassifier
XGB = XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
              colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
              eval_metric='logloss', gamma=0.1, gpu_id=-1, importance_type=None,
              interaction_constraints='', learning_rate=0.1, max_delta_step=0,
              max_depth=6, min_child_weight=10,
              monotone_constraints='()', n_estimators=100, n_jobs=4,
              num_parallel_tree=1, predictor='auto', random_state=0,
              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
              tree_method='exact', use_label_encoder=False,
              validate_parameters=1, verbosity=None)
XGB.fit(X_train,y_train)
y_pred_xg=XGB.predict(X_test)
print(classification_report(y_test,y_pred_xg))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       575
#            1       0.99      0.89      0.94        92
#
#     accuracy                           0.98       667
#    macro avg       0.99      0.94      0.96       667
# weighted avg       0.98      0.98      0.98       667

# %%
from sklearn.ensemble import RandomForestClassifier

rbn=RandomForestClassifier(criterion='gini', max_depth=9, max_features='log2', n_estimators=300, min_samples_split=5)
rbn.fit(X_train,y_train)
y_pred_gd=rbn.predict(X_test)
print(classification_report(y_test,y_pred_gd))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99       575
#            1       1.00      0.91      0.95        92
#
#     accuracy                           0.99       667
#    macro avg       0.99      0.96      0.97       667
# weighted avg       0.99      0.99      0.99       667

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.neighbors import KNeighborsClassifier

# %%
model=LogisticRegression()
model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_test_pred=model.predict(X_test)

# %%
accuracy_score(y_test,y_test_pred)
# Out:
# 0.8620689655172413

# %%
model=DecisionTreeClassifier()
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_test_pred=model.predict(X_test)

# %%
accuracy_score(y_test,y_test_pred)
# Out:
# 0.9535232383808095

# %%
model = KNeighborsClassifier()
model.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_test_pred=model.predict(X_test)

# %%
accuracy_score(y_test,y_test_pred)
# Out:
# 0.8800599700149925

# %%
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation
import seaborn as sns
import statsmodels.api as sm

# %%
models=[DecisionTreeClassifier(),LogisticRegression(),KNeighborsClassifier()]
for model in models:
    model.fit(X_train,y_train)
    y_test_pred=model.predict(X_test)
    print(str(model),"accuracy ::",metrics.accuracy_score(y_test,y_test_pred))
# Out:
# DecisionTreeClassifier() accuracy :: 0.95952023988006
# LogisticRegression() accuracy :: 0.8620689655172413
# KNeighborsClassifier() accuracy :: 0.8800599700149925

# %% [markdown]
# # Now we will work with imablanced dataset techniques

# %%
# visualize the target variable
g = sns.countplot(Telecommunication['churn'])
g.set_xticklabels(['0-no-Churn, ','1-Churn'])
plt.show()

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score

# %% [markdown]
# Let’s do this experiment, using simple XGBClassifier and no feature engineering:

# %%
# import linrary
from xgboost import XGBClassifier

xgb_model = XGBClassifier().fit(X_train, y_train)

# predict
xgb_y_predict = xgb_model.predict(X_test)

# accuracy score
xgb_score = accuracy_score(xgb_y_predict, y_test)

print("Accuracy: %.2f%%" % (xgb_score * 100.0))
print('Roc auc score:', roc_auc_score(xgb_y_predict, y_test))
print('F1 core:',f1_score(xgb_y_predict, y_test))
# Out:
# Accuracy: 98.80%
# Roc auc score: 0.9931389365351629
# F1 core: 0.9545454545454545

# %%
confusion_matrix(xgb_y_predict, y_test)
# Out:
# array([[575,   8],
#        [  0,  84]], dtype=int64)

# %%
from sklearn.metrics import confusion_matrix
from matplotlib import pyplot as plt

conf_mat = confusion_matrix(y_true=y_test, y_pred=xgb_y_predict)
print('Confusion matrix:\n', conf_mat)

labels = ['Class 0', 'Class 1']
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(conf_mat, cmap=plt.cm.Blues)
fig.colorbar(cax)
ax.set_xticklabels([''] + labels)
ax.set_yticklabels([''] + labels)
plt.xlabel('Predicted')
plt.ylabel('Expected')
plt.show()
# Out:
# Confusion matrix:
#  [[575   0]
#  [  8  84]]

# %% [markdown]
# # Resampling Technique

# %% [markdown]
# # We will start by separating the class that will be class 0 and class 1.

# %%
# class count
class_count_0, class_count_1 =Telecommunication['churn'].value_counts()

# Separate class
class_0 = Telecommunication[Telecommunication['churn'] == 0]
class_1 = Telecommunication[Telecommunication['churn'] == 1]# print the shape of the class
print('class 0:', class_0.shape)
print('class 1:', class_1.shape)
# Out:
# class 0: (2850, 19)
# class 1: (483, 19)

# %%
class_0.shape
# Out:
# (2850, 19)

# %%
class_1.shape
# Out:
# (483, 19)

# %% [markdown]
# # 1. Random Under-Sampling

# %% [markdown]
# Undersampling can be defined as removing some observations of the majority class. This is done until the majority and minority class is balanced out.

# %%
class_0_under = class_0.sample(class_count_1)
test_under = pd.concat([class_0_under, class_1], axis=0)

print('Random under-sampling:')
print(test_under.churn.value_counts())

test_under.churn.value_counts().plot(kind='bar', title='Count (churn)');
# Out:
# Random under-sampling:
# 0    483
# 1    483
# Name: churn, dtype: int64

# %% [markdown]
# # 2.Random over-sampling

# %% [markdown]
# Oversampling can be defined as adding more copies to the minority class. Oversampling can be a good choice when you don’t have a ton of data to work with.

# %%
class_1_over = class_1.sample(class_count_0, replace=True)
test_over = pd.concat([class_0, class_1_over], axis=0)

print('Random over-sampling:')
print(test_over.churn.value_counts())

test_over.churn.value_counts().plot(kind='bar', title='Count (target)');
# Out:
# Random over-sampling:
# 0    2850
# 1    2850
# Name: churn, dtype: int64

# %% [markdown]
# # Balance data with imbalance learn module

# %%
import numpy
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import np_utils

# %% [markdown]
# # 3. Random under-sampling with imblearn

# %% [markdown]
# easy way to balance the data by randomly selecting a subset of data for the targeted classes. Under-sample the majority class(es) by randomly picking samples with or without replacement

# %%
# import library
from collections import Counter
from imblearn.under_sampling import RandomUnderSampler

rus = RandomUnderSampler(random_state=42, replacement=True)# fit predictor and target variable
x_rus, y_rus = rus.fit_resample(X, y)

print('original dataset shape:', Counter(y))
print('Resample dataset shape', Counter(y_rus))
# Out:
# original dataset shape: Counter({0: 2850, 1: 483})
# Resample dataset shape Counter({0: 483, 1: 483})

# %% [markdown]
# # 4. Random over-sampling with imblearn

# %% [markdown]
# One way to fight imbalance data is to generate new samples in the minority classes. The most naive strategy is to generate new samples by randomly sampling with replacement of the currently available samples. The RandomOverSampler offers such a scheme.

# %%
# import library
from imblearn.over_sampling import RandomOverSampler

ros = RandomOverSampler(random_state=42)
x_ros, y_ros = ros.fit_resample(X, y)

print('Original dataset shape', Counter(y))
print('Resample dataset shape', Counter(y_ros))
# Out:
# Original dataset shape Counter({0: 2850, 1: 483})
# Resample dataset shape Counter({0: 2850, 1: 2850})

# %% [markdown]
# # 5. Under-sampling: Tomek links

# %% [markdown]
# Tomek links are pairs of very close instances but of opposite classes. Removing the instances of the majority class of each pair increases the space between the two classes, facilitating the classification process.
#
# note--Tomek’s link exists if the two samples are the nearest neighbors of each other

# %%
# import library
from imblearn.under_sampling import TomekLinks

tl = RandomOverSampler(sampling_strategy='majority')

# fit predictor and target variable
x_tl, y_tl = ros.fit_resample(X, y)

print('Original dataset shape', Counter(y))
print('Resample dataset shape', Counter(y_ros))
# Out:
# Original dataset shape Counter({0: 2850, 1: 483})
# Resample dataset shape Counter({0: 2850, 1: 2850})

# %% [markdown]
# # 6. Synthetic Minority Oversampling Technique (SMOTE)

# %%
# import library
from imblearn.over_sampling import SMOTE

smote = SMOTE()

# fit predictor and target variable
x_smote, y_smote = smote.fit_resample(X, y)

print('Original dataset shape', Counter(y))
print('Resample dataset shape', Counter(y_ros))
# Out:
# Original dataset shape Counter({0: 2850, 1: 483})
# Resample dataset shape Counter({0: 2850, 1: 2850})

# %% [markdown]
# # 7. NearMiss

# %% [markdown]
# NearMiss is an under-sampling technique. Instead of resampling the Minority class, using a distance, this will make the majority class equal to the minority class.

# %%
from imblearn.under_sampling import NearMiss

nm = NearMiss()

x_nm, y_nm = nm.fit_resample(X, y)

print('Original dataset shape:', Counter(y))
print('Resample dataset shape:', Counter(y_nm))
# Out:
# Original dataset shape: Counter({0: 2850, 1: 483})
# Resample dataset shape: Counter({0: 483, 1: 483})

# %% [markdown]
# # 8. Change the performance metric

# %% [markdown]
# Metrics that can provide better insight are:
#
#
#     Confusion Matrix:a table showing correct predictions and types of incorrect predictions.
#
#     Precision:the number of true positives divided by all positive predictions
#
#     Recall:the number of true positives divided by the number of positive values in the test data
#
#     F1: Score: the weighted average of precision and recall.
#
#     Area Under ROC Curve (AUROC): AUROC represents the likelihood of your model distinguishing observations from two classes.

# %%
x_train1, x_test1, y_train1, y_test1 = train_test_split(x_nm, y_nm, test_size =0.20, random_state=42)

m = XGBClassifier()
m.fit(x_train1, y_train1)
predict_y = m.predict(x_test1)

print('ROCAUC score:',roc_auc_score(y_test1, predict_y))
print('Accuracy score:',accuracy_score(y_test1, predict_y))
print('F1 score:',f1_score(y_test1, predict_y))
# Out:
# ROCAUC score: 0.8928993447201633
# Accuracy score: 0.8865979381443299
# F1 score: 0.89

# %% [markdown]
# # 9. penalize algorithm

# %% [markdown]
# # Let’s train a model using Penalized-SVM on the original imbalanced dataset

# %%
# load library
from sklearn.svm import SVC
from sklearn.metrics import roc_auc_score
from sklearn.metrics import f1_score
# we can add class_weight='balanced' to add panalize mistake
svc_model = SVC(class_weight='balanced', probability=True)

svc_model.fit(X_train, y_train)

svc_predict = svc_model.predict(X_test)# check performance
print('ROCAUC score:',roc_auc_score(y_test, svc_predict))
print('Accuracy score:',accuracy_score(y_test, svc_predict))
print('F1 score:',f1_score(y_test, svc_predict))
# Out:
# ROCAUC score: 0.7080434782608696
# Accuracy score: 0.8350824587706147
# F1 score: 0.47115384615384615

# %% [markdown]
# # 10.Tree based algorithm

# %%
# load library
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()
# fit the predictor and target
rfc.fit(X_train, y_train)
# predict
rfc_predict = rfc.predict(X_test)# check performance
print('ROCAUC score:',roc_auc_score(y_test, rfc_predict))
print('Accuracy score:',accuracy_score(y_test, rfc_predict))
print('F1 score:',f1_score(y_test, rfc_predict))
# Out:
# ROCAUC score: 0.9502173913043478
# Accuracy score: 0.9850074962518741
# F1 score: 0.9431818181818182

# %% [markdown]
# # Searching optimal value from a grid

# %%
from sklearn.model_selection import train_test_split
from imblearn.ensemble import BalancedRandomForestClassifier
brf = BalancedRandomForestClassifier()
brf.fit(X_train,y_train)
brf.score(X_train,y_train)
# Out:
# 0.9891222805701425

# %%
brf.score(X_test,y_test)
# Out:
# 0.9535232383808095

# %%
from sklearn.ensemble import RandomForestClassifier
rf_model = RandomForestClassifier()
rf_model.fit(X_train,y_train)   
rf_model.predict_proba(X_test) #probability of the class label
# Out:
# array([[1.  , 0.  ],
#        [0.98, 0.02],
#        [0.99, 0.01],
#        ...,
#        [0.93, 0.07],
#        [0.98, 0.02],
#        [0.19, 0.81]])

# %%
step_factor = 0.05 
threshold_value = 0.2 
roc_score=0
predicted_proba = rf_model.predict_proba(X_test) #probability of prediction
while threshold_value <=0.8: #continue to check best threshold upto probability 0.8
    temp_thresh = threshold_value
    predicted = (predicted_proba [:,1] >= temp_thresh).astype('int') #change the class boundary for prediction
    print('Threshold',temp_thresh,'--',roc_auc_score(y_test, predicted))
    if roc_score<roc_auc_score(y_test, predicted): #store the threshold for best classification
        roc_score = roc_auc_score(y_test, predicted)
        thrsh_score = threshold_value
    threshold_value = threshold_value + step_factor
print('---Optimum Threshold ---',thrsh_score,'--ROC--',roc_score)
# Out:
# Threshold 0.2 -- 0.9330434782608695
# Threshold 0.25 -- 0.9452173913043479
# Threshold 0.3 -- 0.9530434782608695
# Threshold 0.35 -- 0.9539130434782609
# Threshold 0.39999999999999997 -- 0.9556521739130435
# Threshold 0.44999999999999996 -- 0.9556521739130435
# Threshold 0.49999999999999994 -- 0.9556521739130435
# Threshold 0.5499999999999999 -- 0.9456521739130435
# Threshold 0.6 -- 0.9456521739130435
# Threshold 0.65 -- 0.9239130434782609
# Threshold 0.7000000000000001 -- 0.875
# Threshold 0.7500000000000001 -- 0.8260869565217391
# ---Optimum Threshold --- 0.39999999999999997 --ROC-- 0.9556521739130435

# %% [markdown]
# # Machine Learning Model Evaluations and Predictions

# %%
knn_model = KNeighborsClassifier(n_neighbors = 11) 
knn_model.fit(X_train,y_train)
predicted_y = knn_model.predict(X_test)
accuracy_knn = knn_model.score(X_test,y_test)
print("KNN accuracy:",accuracy_knn)
# Out:
# KNN accuracy: 0.8845577211394303

# %%
print(classification_report(y_test, predicted_y))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.98      0.94       575
#            1       0.73      0.26      0.38        92
#
#     accuracy                           0.88       667
#    macro avg       0.81      0.62      0.66       667
# weighted avg       0.87      0.88      0.86       667

# %%
svc_model = SVC(random_state = 1)
svc_model.fit(X_train,y_train)
predict_y = svc_model.predict(X_test)
accuracy_svc = svc_model.score(X_test,y_test)
print("SVM accuracy is :",accuracy_svc)
# Out:
# SVM accuracy is : 0.863568215892054

# %%
print(classification_report(y_test, predict_y))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.93       575
#            1       1.00      0.01      0.02        92
#
#     accuracy                           0.86       667
#    macro avg       0.93      0.51      0.47       667
# weighted avg       0.88      0.86      0.80       667

# %%
model_rf = RandomForestClassifier(n_estimators=500 , oob_score = True, n_jobs = -1,
                                  random_state =50, max_features = "auto",
                                  max_leaf_nodes = 30)
model_rf.fit(X_train, y_train)

# Make predictions
prediction_test = model_rf.predict(X_test)
print (metrics.accuracy_score(y_test, prediction_test))
# Out:
# 0.9835082458770614

# %%
print(classification_report(y_test, prediction_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       575
#            1       1.00      0.88      0.94        92
#
#     accuracy                           0.98       667
#    macro avg       0.99      0.94      0.96       667
# weighted avg       0.98      0.98      0.98       667

# %%
plt.figure(figsize=(4,3))
sns.heatmap(confusion_matrix(y_test, prediction_test),
                annot=True,fmt = "d",linecolor="k",linewidths=3)
    
plt.title(" RANDOM FOREST CONFUSION MATRIX",fontsize=14)
plt.show()

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import auc
y_rfpred_prob = model_rf.predict_proba(X_test)[:,1]
fpr_rf, tpr_rf, thresholds = roc_curve(y_test, y_rfpred_prob)
plt.plot([0, 1], [0, 1], 'k--' )
plt.plot(fpr_rf, tpr_rf, label='Random Forest',color = "r")
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Random Forest ROC Curve',fontsize=16)
plt.show();

# %%
lr_model = LogisticRegression()
lr_model.fit(X_train,y_train)
accuracy_lr = lr_model.score(X_test,y_test)
print("Logistic Regression accuracy is :",accuracy_lr)
# Out:
# Logistic Regression accuracy is : 0.8620689655172413

# %%
lr_pred= lr_model.predict(X_test)
report = classification_report(y_test,lr_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.99      0.92       575
#            1       0.50      0.09      0.15        92
#
#     accuracy                           0.86       667
#    macro avg       0.69      0.54      0.54       667
# weighted avg       0.82      0.86      0.82       667

# %%
plt.figure(figsize=(4,3))
sns.heatmap(confusion_matrix(y_test, lr_pred),
                annot=True,fmt = "d",linecolor="k",linewidths=3)
    
plt.title("LOGISTIC REGRESSION CONFUSION MATRIX",fontsize=14)
plt.show()

# %%
y_pred_prob = lr_model.predict_proba(X_test)[:,1]
fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)
plt.plot([0, 1], [0, 1], 'k--' )
plt.plot(fpr, tpr, label='Logistic Regression',color = "r")
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Logistic Regression ROC Curve',fontsize=16)
plt.show();

# %%
dt_model = DecisionTreeClassifier()
dt_model.fit(X_train,y_train)
predictdt_y = dt_model.predict(X_test)
accuracy_dt = dt_model.score(X_test,y_test)
print("Decision Tree accuracy is :",accuracy_dt)
# Out:
# Decision Tree accuracy is : 0.9565217391304348

# %%
print(classification_report(y_test, predictdt_y))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.97       575
#            1       0.81      0.90      0.85        92
#
#     accuracy                           0.96       667
#    macro avg       0.89      0.93      0.91       667
# weighted avg       0.96      0.96      0.96       667

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
gb = GradientBoostingClassifier()
gb.fit(X_train, y_train)
gb_pred = gb.predict(X_test)
print("Gradient Boosting Classifier", accuracy_score(y_test, gb_pred))
# Out:
# Gradient Boosting Classifier 0.9805097451274363

# %%
print(classification_report(y_test, gb_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       575
#            1       0.94      0.91      0.93        92
#
#     accuracy                           0.98       667
#    macro avg       0.96      0.95      0.96       667
# weighted avg       0.98      0.98      0.98       667

# %%
plt.figure(figsize=(4,3))
sns.heatmap(confusion_matrix(y_test, gb_pred),
                annot=True,fmt = "d",linecolor="k",linewidths=3)
    
plt.title("Gradient Boosting Classifier Confusion Matrix",fontsize=14)
plt.show()

# %%
# pickling the model
import pickle
pickle_out = open("gb.pkl", "wb")
pickle.dump(gb, pickle_out)
pickle_out.close()
